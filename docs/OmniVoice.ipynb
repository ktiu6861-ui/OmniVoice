# %% [markdown]
# <a href="https://colab.research.google.com/github/ktiu6861-ui/OmniVoice/blob/master/docs/OmniVoice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OmniVoice Quick Start
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/k2-fsa/OmniVoice/blob/master/docs/OmniVoice.ipynb)
#
# This notebook demonstrates the basic usage of [OmniVoice](https://github.com/k2-fsa/OmniVoice), a massively multilingual zero-shot TTS model supporting 600+ languages.
#
# **Contents:**
# 1. Installation
# 2. Option A — Gradio Demo (interactive web UI, no code needed)
# 3. Option B — Python API
#    - 3.1 Load Model
#    - 3.2 Voice Cloning
#    - 3.3 Voice Design
#    - 3.4 Auto Voice

# %% [markdown]
# ## 1. Installation
#
# Colab already provides a compatible PyTorch + CUDA environment, so we only need to install OmniVoice.

# %%
# !pip install omnivoice
# Out:
# Collecting omnivoice
#   Downloading omnivoice-0.1.5-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from omnivoice) (1.14.0)
# Requirement already satisfied: gradio in /usr/local/lib/python3.12/dist-packages (from omnivoice) (6.19.0)
# Requirement already satisfied: librosa in /usr/local/lib/python3.12/dist-packages (from omnivoice) (0.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from omnivoice) (2.0.2)
# Requirement already satisfied: pydub in /usr/local/lib/python3.12/dist-packages (from omnivoice) (0.25.1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.12/dist-packages (from omnivoice) (0.14.0)
# Collecting tensorboardx (from omnivoice)
#   Downloading tensorboardx-2.6.5-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: torch>=2.4 in /usr/local/lib/python3.12/dist-packages (from omnivoice) (2.11.0+cpu)
# Requirement already satisfied: torchaudio>=2.4 in /usr/local/lib/python3.12/dist-packages (from omnivoice) (2.11.0+cpu)
# Requirement already satisfied: transformers>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from omnivoice) (5.12.1)
# Collecting webdataset (from omnivoice)
#   Downloading webdataset-1.0.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (3.29.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (4.15.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4->omnivoice) (2025.3.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (1.20.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (0.22.2)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (0.25.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /usr/local/lib/python3.12/dist-packages (from transformers>=5.3.0->omnivoice) (4.67.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate->omnivoice) (5.9.5)
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (4.14.0)
# Requirement already satisfied: brotli>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (1.2.0)
# Requirement already satisfied: fastapi<1.0,>=0.115.2 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.138.0)
# Requirement already satisfied: gradio-client==2.5.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (2.5.0)
# Requirement already satisfied: groovy~=0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.1.2)
# Requirement already satisfied: hf-gradio<1.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.4.1)
# Requirement already satisfied: httpx<1.0,>=0.24.1 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.28.1)
# Requirement already satisfied: markupsafe<4.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (3.0.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (3.11.9)
# Requirement already satisfied: pandas<4.0,>=1.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (2.2.2)
# Requirement already satisfied: pillow<13.0,>=8.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (11.3.0)
# Requirement already satisfied: pydantic<=3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (2.13.4)
# Requirement already satisfied: python-multipart<1.0,>=0.0.18 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.0.32)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (2025.2)
# Requirement already satisfied: safehttpx<0.2.0,>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.1.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (2.10.0)
# Requirement already satisfied: starlette<2.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (1.3.1)
# Requirement already satisfied: tomlkit<0.15.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.14.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from gradio->omnivoice) (0.49.0)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (3.1.0)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (0.60.0)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (1.16.3)
# Requirement already satisfied: scikit-learn>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (1.6.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (1.5.3)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (4.4.2)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (1.9.0)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (1.1.0)
# Requirement already satisfied: lazy_loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (0.5)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.12/dist-packages (from librosa->omnivoice) (1.2.1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.12/dist-packages (from soundfile->omnivoice) (2.0.0)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.12/dist-packages (from tensorboardx->omnivoice) (5.29.6)
# Collecting braceexpand (from webdataset->omnivoice)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0,>=3.0->gradio->omnivoice) (3.18)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0->soundfile->omnivoice) (3.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio->omnivoice) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1.0,>=0.115.2->gradio->omnivoice) (0.0.4)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->omnivoice) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.24.1->gradio->omnivoice) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.24.1->gradio->omnivoice) (0.16.0)
# Requirement already satisfied: click>=8.4.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=5.3.0->omnivoice) (8.4.2)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.5.0->transformers>=5.3.0->omnivoice) (1.5.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.12/dist-packages (from numba>=0.51.0->librosa->omnivoice) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio->omnivoice) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=1.0->gradio->omnivoice) (2026.2)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->omnivoice) (4.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.12/dist-packages (from pooch>=1.1->librosa->omnivoice) (2.32.4)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio->omnivoice) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<=3.0,>=2.0->gradio->omnivoice) (2.46.4)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.1.0->librosa->omnivoice) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4->omnivoice) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=5.3.0->omnivoice) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/dist-packages (from typer->transformers>=5.3.0->omnivoice) (13.9.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<4.0,>=1.0->gradio->omnivoice) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->omnivoice) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa->omnivoice) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=5.3.0->omnivoice) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=13.8.0->typer->transformers>=5.3.0->omnivoice) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers>=5.3.0->omnivoice) (0.1.2)
# Downloading omnivoice-0.1.5-py3-none-any.whl (162 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 5.6 MB/s eta 0:00:00
# Downloading tensorboardx-2.6.5-py3-none-any.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.5/87.5 kB 4.1 MB/s eta 0:00:00
# Downloading webdataset-1.0.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.9 MB/s eta 0:00:00
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Installing collected packages: braceexpand, webdataset, tensorboardx, omnivoice
# Successfully installed braceexpand-0.1.7 omnivoice-0.1.5 tensorboardx-2.6.5 webdataset-1.0.2

# %% [markdown]
# ## 2. Option A — Gradio Demo
#
# Launch an interactive web UI with a public Gradio link. The `--share` flag creates a temporary public URL so you can access the demo from any browser.
#
# > **If you prefer to use the Python API directly, skip to Option B below.**

# %%
# !omnivoice-demo --share
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# 2026-07-01 07:58:04,099 root INFO: Loading model from k2-fsa/OmniVoice, device=cpu ...
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Fetching 13 files:   0% 0/13 [00:00<?, ?it/s]Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-07-01 07:58:04,380 huggingface_hub.utils._http WARNING: Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading (incomplete total...):   0% 10.8k/806M [00:00<6:25:53, 34.8kB/s]
# Downloading (incomplete total...):  39% 1.29G/3.27G [00:23<00:41, 47.3MB/s]
# Downloading (incomplete total...): 100% 3.27G/3.27G [00:59<00:00, 57.2MB/s]
# Fetching 13 files: 100% 13/13 [00:59<00:00,  4.59s/it]
# Download complete: 100% 3.27G/3.27G [01:00<00:00, 53.9MB/s]
# Loading weights: 100% 313/313 [00:02<00:00, 129.25it/s]
# Loading weights: 100% 527/527 [00:00<00:00, 1518.59it/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...): 100% 1.52k/1.52k [00:00<00:00, 12.6kB/s]
# Downloading (incomplete total...):   0% 115k/1.62G [00:00<48:03, 561kB/s]
# Downloading (incomplete total...):  29% 474M/1.62G [00:08<00:20, 56.1MB/s]
# Downloading (incomplete total...): 100% 1.62G/1.62G [00:28<00:00, 59.4MB/s]
# Fetching 13 files: 100% 13/13 [00:28<00:00,  2.17s/it]
# Download complete: 100% 1.62G/1.62G [00:28<00:00, 59.4MB/s]
# Loading weights:   0% 0/587 [00:00<?, ?it/s]
# Loading weights:  12% 73/587 [00:00<00:00, 729.73it/s]
# Loading weights:  25% 146/587 [00:00<00:01, 397.44it/s]
# Loading weights:  33% 194/587 [00:00<00:01, 377.79it/s]
# Loading weights:  40% 236/587 [00:00<00:01, 326.86it/s]
# Loading weights:  46% 272/587 [00:00<00:00, 322.48it/s]
# Loading weights:  52% 306/587 [00:00<00:01, 277.88it/s]
# Loading weights:  57% 336/587 [00:01<00:00, 273.03it/s]
# Loading weights:  62% 366/587 [00:01<00:00, 261.70it/s]
# Loading weights:  68% 399/587 [00:01<00:00, 271.46it/s]
# Loading weights:  73% 427/587 [00:01<00:00, 265.15it/s]
# Loading weights:  78% 456/587 [00:01<00:00, 264.26it/s]
# Loading weights:  82% 484/587 [00:01<00:00, 264.91it/s]
# Loading weights:  88% 515/587 [00:01<00:00, 277.18it/s]
# Loading weights:  93% 544/587 [00:01<00:00, 262.16it/s]
# Loading weights: 100% 587/587 [00:01<00:00, 298.48it/s]
# Model loaded.
# /usr/local/lib/python3.12/dist-packages/omnivoice/cli/demo.py:306: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: theme, css. Please pass these parameters to launch() instead.
#   with gr.Blocks(theme=theme, css=css, title="OmniVoice Demo") as demo:
# 2026-07-01 07:59:42,897 httpx INFO: HTTP Request: HEAD https://huggingface.co/api/telemetry/https%3A/api.gradio.app/gradio-initiated-analytics "HTTP/1.1 200 OK"
# 2026-07-01 07:59:43,231 httpx INFO: HTTP Request: GET https://api.gradio.app/pkg-version "HTTP/1.1 200 OK"
# * Running on local URL:  http://0.0.0.0:7860
# 2026-07-01 07:59:43,653 httpx INFO: HTTP Request: GET http://localhost:7860/gradio_api/startup-events "HTTP/1.1 200 OK"
# 2026-07-01 07:59:43,735 httpx INFO: HTTP Request: HEAD http://localhost:7860/ "HTTP/1.1 200 OK"
# 2026-07-01 07:59:44,119 httpx INFO: HTTP Request: GET https://api.gradio.app/v3/tunnel-request "HTTP/1.1 200 OK"
# 2026-07-01 07:59:44,491 httpx INFO: HTTP Request: GET https://cdn-media.huggingface.co/frpc-gradio-0.3/frpc_linux_amd64 "HTTP/1.1 200 OK"
# * Running on public URL: https://7a588d22aabe3ea919.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-07-01 07:59:45,303 httpx INFO: HTTP Request: HEAD https://huggingface.co/api/telemetry/https%3A/api.gradio.app/gradio-launched-telemetry "HTTP/1.1 200 OK"
# Download complete: 100% 1.62G/1.62G [00:42<00:00, 59.4MB/s]

# %% [markdown]
# ## 3. Option B — Python API
#
# ### 3.1 Load Model

# %%
from omnivoice import OmniVoice
import soundfile as sf
import torch
from IPython.display import Audio, display

model = OmniVoice.from_pretrained(
    "k2-fsa/OmniVoice",
    device_map="cuda:0",
    dtype=torch.float16,
    load_asr=True,
)

# %% [markdown]
# ### 3.2 Voice Cloning
#
# Clone a voice from a short (3-10s) reference audio clip. Upload your own `ref.wav` or use any audio file.
#
# `ref_text` is optional — if omitted, the model uses Whisper ASR to auto-transcribe it.

# %%
from google.colab import files

print("Upload a reference audio file (wav/mp3/flac):")
uploaded = files.upload()
ref_audio_path = list(uploaded.keys())[0]
print(f"Uploaded: {ref_audio_path}")

# %%
audio = model.generate(
    text="Hello, this is a test of zero-shot voice cloning.",
    ref_audio=ref_audio_path,
    # ref_text="Transcription of the reference audio.",  # optional
)

sf.write("clone_out.wav", audio[0], 24000)
display(Audio(audio[0], rate=24000))

# %% [markdown]
# ### 3.3 Voice Design
#
# Describe the desired voice with speaker attributes — no reference audio needed.
#
# Supported attributes: gender, age, pitch, style (whisper), English accent, Chinese dialect. See [docs/voice-design.md](https://github.com/k2-fsa/OmniVoice/blob/master/docs/voice-design.md) for the full list.

# %%
audio = model.generate(
    text="Hello, this is a test of zero-shot voice design.",
    instruct="female, low pitch, british accent",
)

sf.write("design_out.wav", audio[0], 24000)
display(Audio(audio[0], rate=24000))

# %% [markdown]
# ### 3.4 Auto Voice
#
# Let the model choose a voice automatically — no reference audio or instruct needed.

# %%
audio = model.generate(
    text="This is a sentence generated with automatic voice selection.",
)

sf.write("auto_out.wav", audio[0], 24000)
display(Audio(audio[0], rate=24000))
